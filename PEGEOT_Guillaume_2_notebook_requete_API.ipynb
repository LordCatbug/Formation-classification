# %%
from stackapi import StackAPI
import pandas as pd 
import time
from datetime import datetime

# %%
def get_data_from_StackAPI(start_date=int(time.mktime(datetime(2023, 1, 1).timetuple())),
                           end_date=int(time.mktime(
                               datetime(2023, 12, 31, 23, 59, 59).timetuple())),
                           score_min=50,
                           filter_code='!.I1Z-vjt(hd9(yOJasMPIz(eE0)Ob'):
    '''
    Retrieves data from Stack Overflow API using specified parameters.

    Parameters:
    - start_date (int, optional): Unix timestamp for the start date (default: January 1, 2023).
    - end_date (int, optional): Unix timestamp for the end date (default: December 31, 2023).
    - score_min (int, optional): Minimum score for questions to retrieve (default: 50).
    - filter_code (str, optional): Filter code for Stack Exchange API to specify which fields to retrieve (default: '!.I1Z-vjt(hd9(yOJasMPIz(eE0)Ob').
                                    You can define your filter here : https://api.stackexchange.com/docs/advanced-search#order=desc&sort=activity&filter=!.I1Z-vjt(hd9(yOJasMPIz(eE0)Ob&site=stackoverflow&run=true

    Returns:
    - DataFrame: Pandas DataFrame containing the retrieved data.
    '''
    # Initialisation de l'API Stack Overflow
    SITE = StackAPI('stackoverflow')
    data = []
    questions = SITE.fetch('questions', fromdate=start_date, todate=end_date,
                           min=50, sort='votes', tagged='python', filter=filter_code)

    # Remplissage de la liste avec les principales caractéristiques des questions
    for item in questions['items']:
        question_id = item['question_id']
        creation_date = pd.to_datetime(item['creation_date'], unit='s')
        score = item['score']
        # Certains champs peuvent être absents
        view_count = item.get('view_count', 0)
        answer_count = item.get('answer_count', 0)
        comment_count = item.get('comment_count', 0)
        favorite_count = item.get('favorite_count', 0)
        title = item['title']
        body = item.get('body', '')  # Certains champs peuvent être absents
        tags = item['tags']

        data.append({
            'Question_ID': question_id,
            'CreationDate': creation_date,
            'Score': score,
            'ViewCount': view_count,
            'AnswerCount': answer_count,
            'CommentCount': comment_count,
            'FavoriteCount': favorite_count,
            'Title': title,
            'Body': body,
            'Tags': tags,
            'Post': title + " " + body
        })

    return pd.DataFrame(data)

# %%
data = get_data_from_StackAPI()
print(data)
# Out:
#     Question_ID        CreationDate  Score  ViewCount  AnswerCount  \
# 0      75608323 2023-03-01 19:52:19    400     667446           28
# 1      75956209 2023-04-07 07:05:59    253     507852            3
# 2      77213053 2023-10-02 03:02:00    166     140036            6
# 3      75898276 2023-03-31 11:58:04    147     312859            5
# 4      76187256 2023-05-06 05:11:42    136     305230           15
# 5      75602063 2023-03-01 09:53:49    113     266551           11
# 6      77364550 2023-10-26 06:22:24    107     126043            7
# 7      74981558 2023-01-02 10:57:36     97      96720            4
# 8      76616042 2023-07-04 21:58:01     87     137227            8
# 9      75495800 2023-02-18 19:19:23     85     107935            9
# 10     75397736 2023-02-09 11:08:22     79      50022            5
# 11     75269700 2023-01-28 17:54:09     78      15548            5
# 12     75804599 2023-03-21 17:35:10     69      70954            4
# 13     76414514 2023-06-06 12:10:43     63      84115           12
# 14     77634955 2023-12-10 13:17:37     62       9784            1
# 15     75354384 2023-02-05 18:04:17     57       6192            2
# 16     75614728 2023-03-02 11:19:35     50      81634            9
#
#     CommentCount  FavoriteCount  \
# 0              4              0
# 1              2              0
# 2              2              0
# 3              8              0
# 4              2              0
# 5              6              0
# 6              0              0
# 7              3              0
# 8              5              0
# 9              3              0
# 10             1              0
# 11             0              0
# 12             0              0
# 13             4              0
# 14             9              0
# 15             8              0
# 16             5              0
#
#                                                 Title  \
# 0   How do I solve &quot;error: externally-managed...
# 1   Error &quot;&#39;DataFrame&#39; object has no ...
# 2   Why did Flask start failing with &quot;ImportE...
# 3   OpenAI API error 429: &quot;You exceeded your ...
# 4   ImportError: urllib3 v2.0 only supports OpenSS...
# 5   pip install -r requirements.txt is failing: &q...
# 6   AttributeError: module &#39;pkgutil&#39; has n...
# 7   Error Updating Python3 pip AttributeError: mod...
# 8   AttributeError: module &#39;PIL.Image&#39; has...
# 9   Error: Unable to extract uploader id - Youtube...
# 10  Poetry install on an existing project Error &q...
# 11  pre-commit fails to install isort 5.11.4 with ...
# 12  OpenAI API: How do I count tokens before(!) I ...
# 13  &quot;cannot import name &#39;DEFAULT_CIPHERS&...
# 14                    Why is the simpler loop slower?
# 15  Why is b.pop(0) over 200 times slower than del...
# 16  Cuda 12 + tf-nightly 2.12: Could not find cuda...
#
#                                                  Body  \
# 0   <p>Error message:</p>\n<blockquote>\n<pre clas...
# 1   <p>I am trying to append a dictionary to a Dat...
# 2   <p>Environment:</p>\n<pre class="lang-none pre...
# 3   <p>I'm making a Python script to use OpenAI vi...
# 4   <p>After <code>pip install openai</code>, when...
# 5   <p>Command:</p>\n<pre class="lang-none prettyp...
# 6   <p>Earlier I installed some packages like <a h...
# 7   <p>I'm having an error when installing/updatin...
# 8   <ul>\n<li>I am trying to have images in my Tki...
# 9   <p>I have a very powerful bot in discord (disc...
# 10  <p>I am using Poetry for the first time.\nI ha...
# 11  <p><a href="https://pre-commit.com/" rel="nore...
# 12  <p>OpenAI's text models have a context length,...
# 13  <h1>What I want to achieve</h1>\n<p>To scrape ...
# 14  <p>Called with <code>n = 10**8</code>, the sim...
# 15  <p>Letting them compete three times (a million...
# 16  <ul>\n<li><strong>tf-nightly version</strong> ...
#
#                                                  Tags  \
# 0                       [python, error-handling, pip]
# 1         [python, pandas, dataframe, attributeerror]
# 2                   [python, flask, pytest, werkzeug]
# 3   [python, prompt, openai-api, completion, chatg...
# 4                       [python, openai-api, urllib3]
# 5                                     [python, linux]
# 6                           [python, python-3.x, pip]
# 7                        [python, ubuntu, pip, wsl-2]
# 8                    [python, python-imaging-library]
# 9               [python, ffmpeg, discord, youtube-dl]
# 10                            [python, python-poetry]
# 11        [python, pre-commit, pre-commit.com, isort]
# 12    [python, openai-api, chatgpt-api, gpt-3, gpt-4]
# 13  [python, amazon-web-services, amazon-s3, aws-l...
# 14  [python, performance, cpython, python-internal...
# 15  [python, arrays, performance, cpython, python-...
# 16                          [python, tensorflow, gpu]
#
#                                                  Post
# 0   How do I solve &quot;error: externally-managed...
# 1   Error &quot;&#39;DataFrame&#39; object has no ...
# 2   Why did Flask start failing with &quot;ImportE...
# 3   OpenAI API error 429: &quot;You exceeded your ...
# 4   ImportError: urllib3 v2.0 only supports OpenSS...
# 5   pip install -r requirements.txt is failing: &q...
# 6   AttributeError: module &#39;pkgutil&#39; has n...
# 7   Error Updating Python3 pip AttributeError: mod...
# 8   AttributeError: module &#39;PIL.Image&#39; has...
# 9   Error: Unable to extract uploader id - Youtube...
# 10  Poetry install on an existing project Error &q...
# 11  pre-commit fails to install isort 5.11.4 with ...
# 12  OpenAI API: How do I count tokens before(!) I ...
# 13  &quot;cannot import name &#39;DEFAULT_CIPHERS&...
# 14  Why is the simpler loop slower? <p>Called with...
# 15  Why is b.pop(0) over 200 times slower than del...
# 16  Cuda 12 + tf-nightly 2.12: Could not find cuda...
